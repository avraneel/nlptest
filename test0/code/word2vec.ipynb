# %%
import gensim
import pandas as pd

# %%
df = pd.read_json('../data/Cell_Phones_and_Accessories_5.json', lines=True)

df.head()
# Out:
#        reviewerID        asin      reviewerName helpful  \
# 0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# 1                      Really great product.      1389657600  01 14, 2014
# ...

# %%
df.shape
df.reviewText[0]
# Out:
# "They look good and stick good! I just don't like the rounded shape because I was always bumping it and Siri kept popping up and it was irritating. I just won't buy a product like this again"

# %%
# Preprocess the text
reviewText = df.reviewText.apply(gensim.utils.simple_preprocess)

# %%
print(reviewText[0][-1])
# Out:
# again

# %%
# Initialising the model
model = gensim.models.Word2Vec(
    window=10,
    min_count=2,
    workers=8,

)

model.save("../models/word2vec.model")

# %%
model.build_vocab(reviewText, progress_per=1000)

# %%
model.epochs
# Out:
# 5

# %%
model.train(reviewText, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (61505971, 83868975)

# %%
model.save("../models/word2vec_trained1.model")

# %%
model.wv.most_similar("../models/good")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.wv.most_similar("../models/good")
#
# File c:\Users\Avraneel Pal\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\models\keyedvectors.py:841, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     838         weight[idx] = item[1]
#     840 # compute the weighted average of all keys
# --> 841 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842 all_keys = [
#     843     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     844 ]
#     846 if indexer is not None and isinstance(topn, int):
#
# ...

# %%
model.wv.similarity(w1="good", w2="iphone")
# Out:
# -0.024199378

# %%
model.wv.similarity(w1="bad", w2="iphone")
# Out:
# -0.22696137

# %%
# find shape of wv
model.wv.vectors.shape
# Out:
# (35561, 100)
